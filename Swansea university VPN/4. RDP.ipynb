# %% [markdown]
# # RDP connection
# We are using XRDP server to host a RDP connection. Open `Remminna`. Click, `+` to create a new connection profile and copy the setting from teh following figure.
#
# ![image.png](attachment:343cab1b-1854-4938-8b7b-66b7e2ac1694.png)

# %% [markdown]
# Now connect to the RDP server, hopefully you will be able to see the screen.
#
# ![image.png](attachment:8b1a5d7e-8019-441a-94c1-cad3118a2d45.png)
